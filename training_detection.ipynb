# %%
# %cd "D:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response"
# Out:
# D:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.246  Python-3.10.0 torch-2.9.1+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# Setup complete  (4 CPUs, 7.8 GB RAM, 20.4/185.5 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")

model.train(
    data="D:/Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response/data.yaml",
    epochs=50,
    imgsz=640,
    batch=16,
    device="cpu"
)

# %%
# !yolo task=detect mode=val model=models/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.246  Python-3.10.0 torch-2.9.1+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access  (ping: 0.40.3 ms, read: 11.83.2 MB/s, size: 116.8 KB)
#
# val: Scanning D:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\data\val\labels... 22 images, 12 backgrounds, 0 corrupt: 11% ━─────────── 22/206 57.8it/s 0.1s<3.2s
# val: Scanning D:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\data\val\labels... 45 images, 25 backgrounds, 0 corrupt: 22% ━━╸───────── 45/206 106.9it/s 0.2s<1.5s
# val: Scanning D:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\data\val\labels... 71 images, 38 backgrounds, 0 corrupt: 34% ━━━━──────── 71/206 142.8it/s 0.3s<0.9s
# ...

# %%
# !yolo task=detect mode=predict model=models/best.pt conf=0.25 source=data/test/images
# Out:
# Ultralytics 8.3.246  Python-3.10.0 torch-2.9.1+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/103 d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\data\test\images\frame12_100.jpg: 384x640 (no detections), 204.6ms
# image 2/103 d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\data\test\images\frame12_180.jpg: 384x640 (no detections), 152.5ms
# image 3/103 d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\data\test\images\frame12_20.jpg: 384x640 (no detections), 146.7ms
# image 4/103 d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\data\test\images\frame12_310.jpg: 384x640 2 accidents, 150.8ms
# ...

# %%
# !yolo task=detect mode=predict model=models/best.pt show=True conf=0.5 source=testing.png
# Out:
# Ultralytics 8.3.246  Python-3.10.0 torch-2.9.1+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\testing.png: 512x640 2 accidents, 223.7ms
# Speed: 2.8ms preprocess, 223.7ms inference, 2.1ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to D:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\runs\detect\predict7
#  Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=models/best.pt show=True conf=0.5 source=testing.mp4
# Out:
# Ultralytics 8.3.246  Python-3.10.0 torch-2.9.1+cpu CPU (11th Gen Intel Core i3-1115G4 @ 3.00GHz)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# video 1/1 (frame 1/374) d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\testing.mp4: 416x640 (no detections), 189.6ms
# video 1/1 (frame 2/374) d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\testing.mp4: 416x640 (no detections), 178.5ms
# video 1/1 (frame 3/374) d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\testing.mp4: 416x640 (no detections), 165.7ms
# video 1/1 (frame 4/374) d:\Autonomous Vehicle Crash Detection and Collision Risk Prediction System for Faster Emergency Response\testing.mp4: 416x640 (no detections), 188.8ms
# ...
